# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Оксана, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провела хорошую работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Оксана, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!
#
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
#
#
#
#
#
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# Hello World!
# Или можешь использовать эту галочку  в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделала огромную работу :)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)

# %% [markdown]
# Привет добавила

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Статистический анализ данных

# %% [markdown]
# - Проект: Статистический анализ данных
# Вы аналитик популярного сервиса аренды самокатов GoFast. Вам передали данные о некоторых пользователях из нескольких городов, а также об их поездках. Проанализируйте данные и проверьте некоторые гипотезы, которые могут помочь бизнесу вырасти.
# Чтобы совершать поездки по городу, пользователи сервиса GoFast пользуются мобильным приложением. Сервисом можно пользоваться:
# - без подписки
#  - абонентская плата отсутствует;
#  - стоимость одной минуты поездки — 8 рублей;
#  - стоимость старта (начала поездки) — 50 рублей;
# - с подпиской Ultra
#  - абонентская плата — 199 рублей в месяц;
#  - стоимость одной минуты поездки — 6 рублей;
#  - стоимость старта — бесплатно.

# %% [markdown]
# Данные:
# - файл с перечнем пользователей в городах с возростом и видом подписки
# - файл с длительностью в метрах и длительностью в минутах
# - файл тип подписки с ценой

# %% [markdown]
# План действий:
# - импортируем библиотеки
# - загружаем данные
# - проводим предобработку данных
# - проводим иследовательский анализ
# - Объединим файлы в один датафрейм
# - Проверим гипотезы H0, Н1

# %% [markdown]
# Добавила описание данных и план действий

# %% [markdown]
# Импорт библиотек

# %%
# импортируем нужные библиотеки
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px

from scipy import stats as st

warnings.filterwarnings("ignore")  # бережем глаза от ненужных предупреждений

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %% [markdown]
# - Считайте CSV-файлы с данными с помощью библиотеки pandas и сохраните их в датафреймы. Пути к файлам:
# - /datasets/users_go.csv
# - /datasets/rides_go.csv
# - /datasets/subscriptions_go.csv

# %% [markdown]
# ##### Загрузим данные /datasets/users_go.csv

# %%
# Прочитаем и выведем на экран данные data_users_go разделитель запятая:
data_users_go = pd.read_csv('/datasets/users_go.csv', sep=',')
pd.set_option('display.max_columns', None)
display(data_users_go)
# Out:
#       user_id        name  age            city subscription_type
# 0           1        Кира   22          Тюмень             ultra
# 1           2   Станислав   31            Омск             ultra
# 2           3     Алексей   20          Москва             ultra
# 3           4  Константин   26  Ростов-на-Дону             ultra
# 4           5       Адель   28            Омск             ultra
# ...       ...         ...  ...             ...               ...
# 1560      829       Федор   29       Пятигорск              free
# 1561      809        Юрий   26            Сочи              free
# 1562      307      Ясмина   19       Краснодар             ultra
# 1563       47        Юрий   28          Тюмень             ultra
# 1564     1045     Артемий   28  Ростов-на-Дону              free
#
# [1565 rows x 5 columns]

# %%
data_users_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %% [markdown]
# Вывод по данным data_users_go:
# - 5 столбцов
# - формат названий удовлетворителен
# - пропущеных значений нет
# - 1565 записей
# - тип данных удовлетворительный

# %% [markdown]
# ##### Загрузим данные /datasets/rides_go.csv

# %%
# Прочитаем и выведем на экран данные data_rides_go разделитель запятая:
data_rides_go= pd.read_csv('/datasets/rides_go.csv', sep=',')
display(data_rides_go)
# Out:
#        user_id     distance   duration        date
# 0            1  4409.919140  25.599769  2021-01-01
# 1            1  2617.592153  15.816871  2021-01-18
# 2            1   754.159807   6.232113  2021-04-20
# 3            1  2694.783254  18.511000  2021-08-11
# 4            1  4028.687306  26.265803  2021-08-28
# ...        ...          ...        ...         ...
# 18063     1534  3781.098080  19.822962  2021-11-04
# 18064     1534  2840.423057  21.409799  2021-11-16
# 18065     1534  3826.185507  18.435051  2021-11-18
# 18066     1534  2902.308661  16.674362  2021-11-27
# 18067     1534  2371.711192  15.893917  2021-12-29
#
# [18068 rows x 4 columns]

# %%
data_rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %% [markdown]
# Вывод по данным data_rides_go:
# - 4 столбца
# - формат названий удовлетворителен
# - пропущеных значений нет
# - 18068 записей
# - тип данных в date не удовлетворительный.

# %% [markdown]
# ##### Загрузим данные /datasets/subscriptions_go.csv

# %%
# Прочитаем и выведем на экран данные data_subscriptions_go разделитель запятая:
data_subscriptions_go = pd.read_csv('/datasets/subscriptions_go.csv', sep=',')
display(data_subscriptions_go)
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %%
data_subscriptions_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# Вывод по данным data_subscriptions_go:
# - 4 столбца
# - формат названий удовлетворителен
# - пропущеных значений нет
# - 2 записи
# - тип данных удовлетворительный.

# %% [markdown]
# Добавила info.
# - Я сначала добавила в шаг загрузки, но потом подумада что должно быть в предобработке данных и переместила
# - Добавила вывод по каждой загрузке.

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %% [markdown]
# - Приведите столбец date к типу даты pandas.
# - Создайте новый столбец с номером месяца на основе столбца date.
# - Проверьте наличие пропущенных значений и дубликатов в датафреймах. Обработайте их, если такие значения присутствуют.

# %% [markdown]
# ##### Приведите столбец date к типу даты pandas.

# %%
display(data_rides_go['date'].head())
# Out:
# 0    2021-01-01
# 1    2021-01-18
# 2    2021-04-20
# 3    2021-08-11
# 4    2021-08-28
# Name: date, dtype: object

# %%
# изменим тип и формат даты data_rides_go['date']
data_rides_go['date'] = pd.to_datetime(data_rides_go['date'], errors='coerce')
data_rides_go['date'] = pd.to_datetime(data_rides_go['date'], format='%m/%d/%Y')

# %% [markdown]
# Нет времени, изменила формат.

# %%
# выведим на экран data_rides_go
display(data_rides_go.head(5))
# Out:
#    user_id     distance   duration       date
# 0        1  4409.919140  25.599769 2021-01-01
# 1        1  2617.592153  15.816871 2021-01-18
# 2        1   754.159807   6.232113 2021-04-20
# 3        1  2694.783254  18.511000 2021-08-11
# 4        1  4028.687306  26.265803 2021-08-28

# %% [markdown]
# Комментарий: тип данных date должен изменится на datetime64

# %%
# выведим info,
data_rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 564.8 KB

# %% [markdown]
# Написала

# %%
# выведим первую и последнию дату data
data_rides_go['date'].min(), data_rides_go['date'].max()
# Out:
# (Timestamp('2021-01-01 00:00:00'), Timestamp('2021-12-30 00:00:00'))

# %% [markdown]
# ##### Создайте новый столбец с номером месяца на основе столбца date.

# %%
# Создадим столбец месяц в data_rides_go
data_rides_go['month'] = data_rides_go['date'].dt.month

# %%
# выведим на экран data_rides_go
display(data_rides_go.head(5))
# Out:
#    user_id     distance   duration       date  month
# 0        1  4409.919140  25.599769 2021-01-01      1
# 1        1  2617.592153  15.816871 2021-01-18      1
# 2        1   754.159807   6.232113 2021-04-20      4
# 3        1  2694.783254  18.511000 2021-08-11      8
# 4        1  4028.687306  26.265803 2021-08-28      8

# %% [markdown]
# ##### Проверьте наличие пропущенных значений и дубликатов в датафреймах. Обработайте их, если такие значения присутствуют.

# %%
# посмотрим info по данным data_users_go
data_users_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %%
# подсчет пропущеных значений data_users_go
data_users_go.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %%
# число явных дубликатов data_users_go
data_users_go.duplicated().sum()
# Out:
# 31

# %%
# выведим дубликаты
data_users_go.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1560     True
# 1561     True
# 1562     True
# 1563     True
# 1564     True
# Length: 1565, dtype: bool

# %%
# создадим duplicate_rows строки дубликаты data_users_go
duplicate_rows = data_users_go[data_users_go.duplicated()]

# %%
# выведим на экран
display(duplicate_rows)
# Out:
#       user_id        name  age            city subscription_type
# 1534      293       Агата   26       Краснодар             ultra
# 1535       16      Амалия   27       Краснодар             ultra
# 1536      909  Константин   20    Екатеринбург              free
# 1537      403      Полина   19            Сочи             ultra
# 1538      908      Рустам   30          Тюмень              free
# 1539       43    Стефания   22            Омск             ultra
# 1540      127       Павел   25       Пятигорск             ultra
# 1541      659       Злата   27  Ростов-на-Дону             ultra
# 1542      204      Руслан   30       Пятигорск             ultra
# 1543      153      Герман   23          Москва             ultra
# 1544     1245      Регина   27       Пятигорск              free
# 1545      807   Александр   28    Екатеринбург              free
# 1546      924       Мария   23       Пятигорск              free
# ...

# %%
# удалим явные дубликаты , дропним data_users_go
data_users_go = data_users_go.drop_duplicates().reset_index(drop=True)

# %%
# число явных дубликатов data_users_go после дропа
data_users_go.duplicated().sum()
# Out:
# 0

# %%
# выведим уникальные города 
data_users_go['city'].unique()
# Out:
# array(['Тюмень', 'Омск', 'Москва', 'Ростов-на-Дону', 'Краснодар',
#        'Пятигорск', 'Екатеринбург', 'Сочи'], dtype=object)

# %%
# посмотрим info по данным data_rides_go
data_rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
#  4   month     18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB

# %%
# подсчет пропущеных значений data_rides_go
data_rides_go.isna().sum()
# Out:
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64

# %%
# число явных дубликатов data_rides_go
data_rides_go.duplicated().sum()
# Out:
# 0

# %%
# посмотрим info по данным data_subscriptions_go
data_subscriptions_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %%
# подсчет пропущеных значений data_subscriptions_go
data_subscriptions_go.isna().sum()
# Out:
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %%
# число явных дубликатов data_subscriptions_go
data_subscriptions_go.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Округлим distance  duration и distance в data_rides_go

# %%
# округлим значения в большую сторону
data_rides_go['duration'] = np.ceil(data_rides_go['duration'])

# %%
# округлим значения в большую сторону
data_rides_go['distance'] = np.ceil(data_rides_go['distance'])

# %%
data_rides_go.head(5)
# Out:
#    user_id  distance  duration       date  month
# 0        1    4410.0      26.0 2021-01-01      1
# 1        1    2618.0      16.0 2021-01-18      1
# 2        1     755.0       7.0 2021-04-20      4
# 3        1    2695.0      19.0 2021-08-11      8
# 4        1    4029.0      27.0 2021-08-28      8

# %%
data_rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
#  4   month     18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB

# %% [markdown]
# ##### Вывод:
# - Изменили тип данных для даты и добавили столбец номер месяца.
# - По данным минимального и максимального значения, период взять только 2021 год.
# - Проверили, пропущеных значений нет
# - Дубликаты удалили из данных data_users_go
# - Округлили значения по учловиям задачи

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# - Шаг 3. Исследовательский анализ данных
# Опишите и визуализируйте общую информацию о пользователях и поездках:
# - 3.1 частота встречаемости городов;
# - 3.2 соотношение пользователей с подпиской и без подписки;
# - 3.3 возраст пользователей;
# - 3.4 расстояние, которое пользователь преодолел за одну поездку;
# - 3.5 продолжительность поездок.

# %% [markdown]
# ##### частота встречаемости городов

# %%
# выведим сводную статистику по city describe
data_users_go['city'].describe()
# Out:
# count          1534
# unique            8
# top       Пятигорск
# freq            219
# Name: city, dtype: object

# %%
data_users_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 60.0+ KB

# %%
#создадим групировку
data_users_go.groupby('city')['user_id'].count().reset_index().sort_values(by='user_id', ascending=False)
# Out:
#              city  user_id
# 4       Пятигорск      219
# 0    Екатеринбург      204
# 5  Ростов-на-Дону      198
# 1       Краснодар      193
# 6            Сочи      189
# 3            Омск      183
# 7          Тюмень      180
# 2          Москва      168

# %%
# Настройка размера фигуры
plt.figure(figsize=(13, 7))

# построим гистограмму
sns.barplot(x="user_id",
            y="city",
            data=data_users_go.groupby('city')['user_id'].count().reset_index().sort_values(by='user_id', ascending=False),
            color='#C0C78C' # код ревьюера
)
# установка заголовка графика
plt.title('Частота встречаемости городов')
# подписи для оси X
plt.xlabel('Количество пользователей')
# подписи для оси Y
plt.ylabel('Город')
# сетка на графике, серого цвета с прозрачностью 0.5
plt.grid(color='grey', axis='both', alpha=0.5)
plt.show()

# %% [markdown]
# Нашла вот такой вид визуализации, но что то не понимаю что бы однотонный был какой параметр ввечти?

# %% [markdown]
# Подписала

# %% [markdown]
# ##### соотношение пользователей с подпиской и без подписки

# %%
# выведим сводную статистику по subscription_type describe
data_users_go['subscription_type'].describe()
# Out:
# count     1534
# unique       2
# top       free
# freq       835
# Name: subscription_type, dtype: object

# %%
# создадим групировку
data_users_go_count = data_users_go['subscription_type'].value_counts()
data_users_go_count
# Out:
# free     835
# ultra    699
# Name: subscription_type, dtype: int64

# %%
# создадим пирог
data_users_go['subscription_type'].value_counts().plot(
    kind = 'pie', 
    y = data_users_go_count, 
    autopct = '%1.0f%%', 
    figsize=(5,5),
    title = 'соотношение пользователей с подпиской и без подписки');

# %% [markdown]
# ##### возраст пользователей

# %%
# выведим сводную статистику по age describe
data_users_go['age'].describe()
# Out:
# count    1534.000000
# mean       24.903520
# std         4.572367
# min        12.000000
# 25%        22.000000
# 50%        25.000000
# 75%        28.000000
# max        43.000000
# Name: age, dtype: float64

# %%
# выведим гистограмму встречаемости возраст, супер путер визуализация

plt.figure(figsize=(5, 5))
sns.histplot(data_users_go['age'], bins=30,)
plt.title('Гистограмма возраст')
plt.xlabel('возрат')
plt.ylabel('кол-во пользователей')
plt.show()

# %% [markdown]
# ##### расстояние, которое пользователь преодолел за одну поездку, данным data_rides_go

# %%
# выведим сводную статистику по distance describe
data_rides_go['distance'].describe()
# Out:
# count    18068.000000
# mean      3071.159841
# std       1116.831548
# min          1.000000
# 25%       2543.750000
# 50%       3134.000000
# 75%       3777.000000
# max       7212.000000
# Name: distance, dtype: float64

# %%
# выведим гистограмму встречаемости дистанция преодоленная, супер путер визуализация

plt.figure(figsize=(5, 5))
sns.histplot(data_rides_go['distance'], bins=30,)
plt.title('Гистограмма пройденой дистанции')
plt.xlabel('дистанция')
plt.ylabel('кол-во заездов')
plt.show()

# %% [markdown]
# Может зависит от города, и его площади. Нужно смотреть по каждому городу думаю.

# %%
plt.hist(data_rides_go['distance'], bins=500, range=(1,1500))
plt.title('Гистограмма пройденой дистанции до 1500')
plt.xlabel('дистанция')
plt.ylabel('Количество поездок')
plt.show()

# %% [markdown]
# ##### продолжительность поездок

# %%
# выведим сводную статистику по duration describe
data_rides_go['duration'].describe()
# Out:
# count    18068.000000
# mean        18.303520
# std          6.094928
# min          1.000000
# 25%         14.000000
# 50%         18.000000
# 75%         22.000000
# max         41.000000
# Name: duration, dtype: float64

# %%
# выведим гистограмму встречаемости дистанция преодоленная, супер путер визуализация

plt.figure(figsize=(5, 5))
sns.histplot(data_rides_go['duration'], bins=30,)
plt.title('Гистограмма продолжительность поездки')
plt.xlabel('продолжительность')
plt.ylabel('кол-во заездов')
plt.show()

# %% [markdown]
# ##### Вывод:
# - 3.1 частота встречаемости городов - Максимальное кол-во пользователей в Пятигорске , самое меньшее в Москве.
#     - Очень странно что в москве мало.
# - 3.2 соотношение пользователей с подпиской и без подписки - Больше пользоватеолей пользуются сервисом без подписки.
# - 3.3 возраст пользователей - Максимальное кол-во пользователей в возрасте 25 лет. Гистограмма нормального распределения
# - 3.4 расстояние, которое пользователь преодолел за одну поездку - Среднее значение пользователей прошло дистанцию 3070. Гистограмма нормального распределения
# - 3.5 продолжительность поездок - Среднее значение пользователей прошло дистанцию 17. Гистограмма нормального распределения. Так же есть минимальное значение подозрительное min 0.500000, возможно самокаты взяли и сразу отменяли поездку.

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# - 4.1 Объедините данные о пользователях, поездках и подписках в один датафрейм. Для этого воспользуйтесь методом merge().
# - 4.2 Создайте ещё два датафрейма из датафрейма, созданного на этапе 4.1:
#   - c данными о пользователях без подписки;
#   - с данными о пользователях с подпиской.
# - 4.3 Визуализируйте информацию о расстоянии и времени поездок для пользователей обеих категорий.

# %% [markdown]
# ##### Объедините данные о пользователях, поездках и подписках в один датафрейм. Для этого воспользуйтесь методом merge()

# %%
# создаем общую таблицу данных через merge
#pd.merge(data_users_go, data_subscriptions_go, data_rides_go)

data = data_users_go.merge(data_subscriptions_go, on='subscription_type', how='left')
data = data.merge(data_rides_go, on='user_id', how='left')

# %%
# выведим на экран
display(data.head(5))
# Out:
#    user_id  name  age    city subscription_type  minute_price  \
# 0        1  Кира   22  Тюмень             ultra             6
# 1        1  Кира   22  Тюмень             ultra             6
# 2        1  Кира   22  Тюмень             ultra             6
# 3        1  Кира   22  Тюмень             ultra             6
# 4        1  Кира   22  Тюмень             ultra             6
#
#    start_ride_price  subscription_fee  distance  duration       date  month
# 0                 0               199    4410.0      26.0 2021-01-01      1
# 1                 0               199    2618.0      16.0 2021-01-18      1
# 2                 0               199     755.0       7.0 2021-04-20      4
# 3                 0               199    2695.0      19.0 2021-08-11      8
# 4                 0               199    4029.0      27.0 2021-08-28      8

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   name               18068 non-null  object
#  2   age                18068 non-null  int64
#  3   city               18068 non-null  object
#  4   subscription_type  18068 non-null  object
#  5   minute_price       18068 non-null  int64
#  6   start_ride_price   18068 non-null  int64
#  7   subscription_fee   18068 non-null  int64
#  8   distance           18068 non-null  float64
#  9   duration           18068 non-null  float64
#  10  date               18068 non-null  datetime64[ns]
#  11  month              18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# ##### Создайте ещё два датафрейма из датафрейма, созданного на этапе 4.1:
#   - c данными о пользователях без подписки;
#   - с данными о пользователях с подпиской.

# %%
# создадим дата ферейм без подписки
data_free = data[data['subscription_type'] == 'free']

# %%
# выведим на экран
display(data_free.head(5))
# Out:
#       user_id   name  age  city subscription_type  minute_price  \
# 6500      700  Айдар   22  Омск              free             8
# 6501      700  Айдар   22  Омск              free             8
# 6502      700  Айдар   22  Омск              free             8
# 6503      700  Айдар   22  Омск              free             8
# 6504      700  Айдар   22  Омск              free             8
#
#       start_ride_price  subscription_fee  distance  duration       date  month
# 6500                50                 0    2516.0      15.0 2021-01-02      1
# 6501                50                 0     847.0      17.0 2021-02-01      2
# 6502                50                 0    4005.0      21.0 2021-02-04      2
# 6503                50                 0    1206.0      10.0 2021-02-10      2
# 6504                50                 0    3048.0      18.0 2021-02-14      2

# %%
# создадим дата ферейм c подпиской
data_ultra = data[data['subscription_type'] == 'ultra']

# %%
# выведим на экран
display(data_ultra.head(5))
# Out:
#    user_id  name  age    city subscription_type  minute_price  \
# 0        1  Кира   22  Тюмень             ultra             6
# 1        1  Кира   22  Тюмень             ultra             6
# 2        1  Кира   22  Тюмень             ultra             6
# 3        1  Кира   22  Тюмень             ultra             6
# 4        1  Кира   22  Тюмень             ultra             6
#
#    start_ride_price  subscription_fee  distance  duration       date  month
# 0                 0               199    4410.0      26.0 2021-01-01      1
# 1                 0               199    2618.0      16.0 2021-01-18      1
# 2                 0               199     755.0       7.0 2021-04-20      4
# 3                 0               199    2695.0      19.0 2021-08-11      8
# 4                 0               199    4029.0      27.0 2021-08-28      8

# %% [markdown]
# ##### Визуализируйте информацию о расстоянии и времени поездок для пользователей обеих категорий.

# %%
# выведим гистограмму дистанция, супер путер визуализация

plt.figure(figsize=(15, 6))
plt.hist([data_free['distance'], data_ultra['distance']], bins=30, label=['free', 'ultra'])
plt.legend(loc='upper right')
plt.title('Гистограмма растояние пользователей подписок free и ultra')
plt.xlabel('дистанция поездки')
plt.ylabel('кол-во поездок')
plt.show()

# %% [markdown]
# Это количество поездок

# %%
# выведим сводную статистику по data_free distance describe
data_free['distance'].describe()
# Out:
# count    11568.000000
# mean      3045.992911
# std       1246.174341
# min          1.000000
# 25%       2367.000000
# 50%       3115.000000
# 75%       3906.000000
# max       7212.000000
# Name: distance, dtype: float64

# %%
# выведим сводную статистику по data_ultra distance describe
data_ultra['distance'].describe()
# Out:
# count    6500.000000
# mean     3115.949231
# std       836.894838
# min       245.000000
# 25%      2786.000000
# 50%      3149.000000
# 75%      3561.000000
# max      5700.000000
# Name: distance, dtype: float64

# %%
# выведим гистограмму продолжительность, супер путер визуализация

plt.figure(figsize=(15, 6))
plt.hist([data_free['duration'], data_ultra['duration']], bins=30, label=['free', 'ultra'])
plt.legend(loc='upper right')
plt.title('Гистограмма продолжительности поездок пользователей без подписок (free) и с подпиской (ultra)')
plt.xlabel('продолжительность поездки')
plt.ylabel('кол-во поездок')
plt.show()

# %%
# выведим сводную статистику по data_free distance describe
data_free['duration'].describe()
# Out:
# count    11568.000000
# mean        17.890992
# std          6.330250
# min          1.000000
# 25%         13.000000
# 50%         18.000000
# 75%         22.000000
# max         35.000000
# Name: duration, dtype: float64

# %%
# выведим сводную статистику по data_ultra distance describe
data_ultra['duration'].describe()
# Out:
# count    6500.000000
# mean       19.037692
# std         5.577439
# min         4.000000
# 25%        15.000000
# 50%        19.000000
# 75%        22.000000
# max        41.000000
# Name: duration, dtype: float64

# %% [markdown]
# ##### Вывод:
# - По гистограмме растояние пользователей подписок free и ultra минимальное значение без подписки 0.85, а по пописке 244, среднее значение дистанции не сильно отличается.
# - По гистограмма продолжительности поездок пользователей без подписок (free) и с подпиской (ultra) минимальное значение без подписки 0.5, а по пописке 3,76, среднее значение дистанции не сильно отличается.

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# - 5.1 Создайте датафрейм с агрегированными данными о поездках на основе датафрейма с объединёнными данными из шага 4:
#   - найдите суммарное расстояние,
#   - количество поездок
#   - суммарное время для каждого пользователя за каждый месяц.
# - 5.2 В этот же датафрейм добавьте столбец с помесячной выручкой, которую принёс каждый пользователь. Для этого обратитесь к информации об условиях оплаты для подписчиков и тех, у кого нет подписки. Продолжительность каждой поездки в каждой строке исходного датафрейма для подсчёта стоимости округляется до следующего целого числа: например, значения 25.3, 25.5 и 26.0 должны быть преобразованы к 26.

# %% [markdown]
# ##### Создайте датафрейм с агрегированными данными о поездках на основе датафрейма с объединёнными данными из шага 4: найдите суммарное расстояние, количество поездок и суммарное время для каждого пользователя за каждый месяц.

# %%
display(data.head(5))
# Out:
#    user_id  name  age    city subscription_type  minute_price  \
# 0        1  Кира   22  Тюмень             ultra             6
# 1        1  Кира   22  Тюмень             ultra             6
# 2        1  Кира   22  Тюмень             ultra             6
# 3        1  Кира   22  Тюмень             ultra             6
# 4        1  Кира   22  Тюмень             ultra             6
#
#    start_ride_price  subscription_fee  distance  duration       date  month
# 0                 0               199    4410.0      26.0 2021-01-01      1
# 1                 0               199    2618.0      16.0 2021-01-18      1
# 2                 0               199     755.0       7.0 2021-04-20      4
# 3                 0               199    2695.0      19.0 2021-08-11      8
# 4                 0               199    4029.0      27.0 2021-08-28      8

# %%
# создадим сводную через пивот
data_month_final = data.pivot_table(
    index=('user_id','month','subscription_type'),
    values=('minute_price','start_ride_price', 'subscription_fee', 'distance','duration'),
    aggfunc=({'distance':{'count', 'sum'}, 
             'duration':'sum',
             'minute_price': 'mean',
             'start_ride_price':'mean',
             'subscription_fee':'mean',})
)

# %%
# выедим на экран data_month_final
display(data_month_final)
# Out:
#                                 distance          duration minute_price  \
#                                    count      sum      sum         mean
# user_id month subscription_type
# 1       1     ultra                    2   7028.0     42.0            6
#         4     ultra                    1    755.0      7.0            6
#         8     ultra                    2   6724.0     46.0            6
#         10    ultra                    2   5811.0     32.0            6
#         11    ultra                    3   7005.0     56.0            6
# ...                                  ...      ...      ...          ...
# 1534    6     free                     2   3411.0     26.0            8
#         8     free                     2   7623.0     48.0            8
#         9     free                     1   4929.0     23.0            8
#         11    free                     4  13353.0     78.0            8
#         12    free                     1   2372.0     16.0            8
# ...

# %%
# переименнуем столбцы
data_month_final.columns = ['count', 'distance_sum','duration_sum','minute_price','start_ride_price', 'subscription_fee']

# %%
# выедим на экран data_month_final
display(data_month_final.head(5))
# Out:
#                                  count  distance_sum  duration_sum  \
# user_id month subscription_type
# 1       1     ultra                  2        7028.0          42.0
#         4     ultra                  1         755.0           7.0
#         8     ultra                  2        6724.0          46.0
#         10    ultra                  2        5811.0          32.0
#         11    ultra                  3        7005.0          56.0
#
#                                  minute_price  start_ride_price  \
# user_id month subscription_type
# 1       1     ultra                         6                 0
#         4     ultra                         6                 0
#         8     ultra                         6                 0
#         10    ultra                         6                 0
#         11    ultra                         6                 0
#
#                                  subscription_fee
# user_id month subscription_type
# ...

# %% [markdown]
# Добавила пункт 2,4 в предобработку данных

# %%
# выедим на экран data_month_final
display(data_month_final.head(5))
# Out:
#                                  count  distance_sum  duration_sum  \
# user_id month subscription_type
# 1       1     ultra                  2        7028.0          42.0
#         4     ultra                  1         755.0           7.0
#         8     ultra                  2        6724.0          46.0
#         10    ultra                  2        5811.0          32.0
#         11    ultra                  3        7005.0          56.0
#
#                                  minute_price  start_ride_price  \
# user_id month subscription_type
# 1       1     ultra                         6                 0
#         4     ultra                         6                 0
#         8     ultra                         6                 0
#         10    ultra                         6                 0
#         11    ultra                         6                 0
#
#                                  subscription_fee
# user_id month subscription_type
# ...

# %% [markdown]
# ##### В этот же датафрейм добавьте столбец с помесячной выручкой, которую принёс каждый пользователь. Для этого обратитесь к информации об условиях оплаты для подписчиков и тех, у кого нет подписки. Продолжительность каждой поездки в каждой строке исходного датафрейма для подсчёта стоимости округляется до следующего целого числа: например, значения 25.3, 25.5 и 26.0 должны быть преобразованы к 26.

# %%
# добавим столбец 'total_sum'
data_month_final['total_sum']=(
    (data_month_final['duration_sum']*(data_month_final['minute_price']))
    +(data_month_final['start_ride_price']*data_month_final['count'])
    +data_month_final['subscription_fee']
)

# %%
# выедим на экран data_month_final
display(data_month_final)
# Out:
#                                  count  distance_sum  duration_sum  \
# user_id month subscription_type
# 1       1     ultra                  2        7028.0          42.0
#         4     ultra                  1         755.0           7.0
#         8     ultra                  2        6724.0          46.0
#         10    ultra                  2        5811.0          32.0
#         11    ultra                  3        7005.0          56.0
# ...                                ...           ...           ...
# 1534    6     free                   2        3411.0          26.0
#         8     free                   2        7623.0          48.0
#         9     free                   1        4929.0          23.0
#         11    free                   4       13353.0          78.0
#         12    free                   1        2372.0          16.0
#
#                                  minute_price  start_ride_price  \
# user_id month subscription_type
# ...

# %%
# выведим сводную статистику по data_free distance describe
data_month_final['total_sum'].describe()
# Out:
# count    11331.000000
# mean       342.303504
# std        153.875346
# min         58.000000
# 25%        234.000000
# 50%        319.000000
# 75%        415.000000
# max       1444.000000
# Name: total_sum, dtype: float64

# %%
# итого сумма по всем пользователям
data_month_final['total_sum'].sum()
# Out:
# 3878641.0

# %% [markdown]
# ##### Вывод:
# - подсчитали выручку за год, она равна 3 878 641 руб.

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# Продакт-менеджеры сервиса хотят увеличить количество пользователей с подпиской. Для этого они будут проводить различные акции, но сначала нужно выяснить несколько важных моментов.
# - 6.1 Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании. Проверьте гипотезу. Используйте исходные данные о продолжительности каждой сессии — отдельно для подписчиков и тех, у кого нет подписки.
# - 6.2 Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров? Проверьте гипотезу и сделайте выводы.
# - 6.3 Проверьте гипотезу о том, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. Сделайте вывод.
# - 6.4 Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?

# %% [markdown]
# ##### Важно понять, тратят ли пользователи с подпиской больше времени на поездки? Если да, то пользователи с подпиской могут быть «выгоднее» для компании. Проверьте гипотезу. Используйте исходные данные о продолжительности каждой сессии — отдельно для подписчиков и тех, у кого нет подписки.

# %% [markdown]
# -  Независимый t-тест (ttest_ind) - Гипотеза о равенстве средних двух генеральных совокупностей
# - scipy.stats.ttest_ind(array1, array2, equal_var, alternative)

# %% [markdown]
# Гипотеза:

# %% [markdown]
# - Нулевая гипотеза H0, время поездки пользователей с подпиской ultra и free равна =.
# - Альтернатичная гипотеза H1, время поездки пользователей с подпиской ultra больше чем без подписки free

# %%
# возьмем среднию продолжительсть без подписки free
free_mean_duration = data_free['duration'].mean()

# %%
# выведим на экран

free_mean_duration.astype('int32')
# Out:
# 17

# %%
# возьмем среднию продолжительсть с подпиской ultra
ultra_mean_duration = data_ultra['duration'].mean()

# %%
ultra_mean_duration.astype('int32')
# Out:
# 19

# %%
# уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу
alpha = 0.05

# %%
# выполним тест 2-х независимых групп, нулевая гипотеза односторонняя
results = st.ttest_ind(data_ultra['duration'], data_free['duration'], alternative = 'greater')
print(results.pvalue)
alpha = 0.05
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 2.4959453720736625e-34
# Отвергаем нулевую гипотезу

# %% [markdown]
# Вывод: отвергаем нулевую гипотезу, время поездок пользователей не равны с подпиской и без подписки, время с подпиской тратят больше чем без подписки

# %% [markdown]
# #####  Расстояние одной поездки в 3130 метров — оптимальное с точки зрения износа самоката. Можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
# - Проверьте гипотезу и сделайте выводыОдновыборочный t-тест (ttest_1samp) - Проверка односторонних гипотез в Python
# - - scipy.stats.ttest_1samp(df, values_var, alternative)

# %% [markdown]
# Гипотеза:

# %% [markdown]
# - Нулевая гипотеза H0, расстояние distance пользователей на подписке ultra равен  3130
# - Альтернатичная гипотеза H1, расстояние distance пользователей на подписке ultra больше 3130 метров

# %%
# одновыборочного t-теста для проверки гипотезы
results = st.ttest_1samp(data_ultra['distance'], 3130, alternative='greater')
print(results.pvalue)
alpha = 0.05
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 0.9120422337080507
# Не удалось отвергнуть нулевую гипотезу

# %% [markdown]
# Вывод:
# - Не отвергаем нулевую гипотезу
# - По альтернативной гипотизе не можем утверждать что по подписке  ultra пользоватили проезжают больше 3130 метров

# %% [markdown]
# Вот так?

# %% [markdown]
# #####  Проверьте гипотезу о том, будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. Сделайте вывод.

# %% [markdown]
# Гипотеза:
# - Нулевая гипотеза H0, выручка month пользователей на подписке ultra = выручка month пользователей на подписке free
# - Альтернатичная гипотеза H1, выручка month пользователей на подписке ultra > выручка month пользователей на подписке free

# %%
results = st.ttest_ind(
    data_month_final.loc[data_month_final['subscription_fee'] > 0, 'total_sum'], 
    data_month_final.loc[data_month_final['subscription_fee'] == 0, 'total_sum'], 
    equal_var=True, 
    alternative='greater')
print(results.pvalue)

alpha = 0.05
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# 1.8850394384715216e-31
# Отвергаем нулевую гипотезу

# %% [markdown]
# Вывод:Отвергаем нулевую гипотезу, выручка помесечная не равна, выруска по подписке больше чем без подписки

# %% [markdown]
# ##### Представьте такую ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Она надеется, что из-за этого количество обращений в техподдержку значимо снизилось. Некоторый файл содержит для каждого пользователя данные о количестве обращений до обновления и после него. Какой тест вам понадобился бы для проверки этой гипотезы?

# %% [markdown]
# Для одной группы используется Парный t-тест (ttest_rel) - Гипотеза о равенстве средних для зависимых (парных) выборок

# %% [markdown]
# #### Шаг 7. Общий вывод:
# - загрузили 3 датафрейма
# - провели предобработку данных
# - провели иследовательский анализ
#  - количество пользователей в городах не сильно отличается, максимальное значение в Пятигорске, минимальное знаечние в Москве
#  - количество людей без подписки больше 54%, с подпиской меньше 46%
#  - больше всего пользователей сервисом в возрасте 25 лет
#  - в среднем пользоватли проезжают 3 км
#  - средняя продолжительность поездок 17 минут
# - объединили 3 датафрейма вместе, все данные подгрузились, пропусков и ошибок не было2
# - провели визуализацию датафреймов
#  - По гистограмме растояние пользователей подписок free и ultra минимальное значение без подписки 0.85, а по пописке 244, среднее значение дистанции не сильно отличается.
#  - По гистограмма продолжительности поездок пользователей без подписок (free) и с подпиской (ultra) минимальное значение без подписки 0.5, а по пописке 3,76, среднее значение дистанции не сильно отличается.
# - посчитали выручку , оно составила 3 878 641 руб.
# - проверили гипотезы:
#  - время поездок пользователей не равны с подпиской и без подписки, время с подпиской тратят больше чем без подписки
#  - выручка не равна, выруска по подписке больше чем без подписки
#  - не можем утверждать, что расстояние, которое проехали пользователи на тарифе ultra не превышает 3130 метров.
#  - не можем утверждать что по подписке  ultra пользоватили проезжают больше 3130 метров

# %% [markdown]
# ##### Рекомендации:
# Пользователи с подпиской выгоднее для компании, поэтому нужно провести маркетинговые программы для того что бы больше пользователей перевести на подписку.
