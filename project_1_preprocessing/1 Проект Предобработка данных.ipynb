# %% [markdown]
# <font face='Liberation serif' size=3>
#
# **Привет!** 👋
#
# Меня зовут Артем Пиляй. Я буду проверять твой проект. В рамках корпоративной этики мы общаемся на «ты». Но если лучше на «Вы», то нужно обозначить это сразу.
#
# В тетрадке есть комментарии к проекту, они будут в отдельных ячейках Markdown.
#
# <div class="alert alert-danger">
#
# **Артём:** ❌ Такой комментарий **нужно исправить** обязательно, он критически влияет на удачное выполнение проекта.
#
# </div>
#
# <div class="alert alert-success">
#
# **Артём:** 👍 Это **главный комментарий**, значит все сделано хорошо. 😉 А еще в таких комментариях бывают подсказки как сделать **твой проект ещё лучше**.
#
# </div>
#
# ---
#
# **Распространенные ошибки**
#
# <div class="alert alert-danger">
#
# **Артём:** ❌ Не перемещай и не удаляй мои комментарии. Лучше, чтобы твои ответы на мои комментарии шли по очереди, как сообщения в мессенджере. Это ускорит проверку.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ❌ Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).
#
# </div>
#
# <div class="alert alert-success">
#
# #### **Артём:** 👍 Кстати, смотри как можно сделать, чтобы датасет грузился и локально, и в JupyterHub:
#
# ```py
# try:
#     df = pd.read_csv('C:/Users/Student/Desktop/dataset.csv')
# except:
#     df = pd.read_csv('/datasets/dataset.csv')
# ```
#
# Используя эту конструкцию в будущих проектах, ты будешь спокойно отправлять проект на проверку зная, что он будет работать.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ❌ Проект должен быть структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ❌ Если с твоим проектом будет знакомиться другой человек, например рекрутер или старший дата специалист, в нем должны быть описаны поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.
#
# </div>
#
# <div class="alert alert-success">
#
# #### **Артём:** 👍 Длинный код и комментарии нужно переносить на новую строку. Согласись, коллеги не оценят, если им придется тратить время на пролистывание ячеек. Согласно международному стандарту [PEP8](https://www.python.org/dev/peps/pep-0008/) длина строки не должна превышать 79 символов.
# Вот как можно перенести код на новую строку:
#
# ```py
# # Переносить можно код внутри скобки
# example = (2 *
#            2)
# ```
# Конечно, я не считаю сколько символов в строке, главное, чтобы код или комментарий не ушел за пределы ячейки (зависит от разрешения экрана). Если ушел, то это желтый комментарий для каждой нечитаемой ячейки.
#
# </div>
#
# <div class="alert alert-success">
#
# #### **Артём:** 👍 Тимлид, старший дата специалист или ревьюер ценят твое и своё время, подсвечивай свои комментарии в ячейках Markdown. Шаблон я тебе оставил ниже. Подробнее про синтаксис Markdown, с примерами, можно почитать [здесь](https://paulradzkov.com/2014/markdown_cheatsheet/?).
#
# </div>
#
# <div class="alert alert-success">
#
# **Артём:** 👍 Буду рад, если воспользуешься моими советами. Они тебе помогут при трудоустройстве, например в [Яндексе](https://yandex.ru/jobs/pages/analytics_interview?ysclid=l84s63fs1g790141490), и при работе в команде. Если в ходе проведения исследования возникнут вопросы, не стесняйся задавай. 🙂
# </div>
#
# <div class="alert alert-info">
#
# **Артём:** 🏁 [Итоги ревью здесь](#results)
# </div>
#
#
# **Поехали!** 🚀 👨‍🚀
# <a id="start"></a>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
#
# **Имя:** ✔️ Это шаблон для тебя. Такой комментарий можно быстро найти.

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
data.info() # Ваш код будет здесь. Вы можете создавать новые ячейки.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21331 entries, 0 to 21524
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   children               21331 non-null  int64
#  1   days_employed          21331 non-null  float64
#  2   dob_years              21331 non-null  int64
#  3   education              21331 non-null  object
#  4   education_id           21331 non-null  int64
#  5   family_status          21331 non-null  object
#  6   family_status_id       21331 non-null  int64
#  7   gender                 21331 non-null  object
#  8   income_type            21331 non-null  object
#  9   debt                   21331 non-null  int64
#  10  total_income           21331 non-null  int64
#  11  purpose                21331 non-null  object
#  12  total_income_category  21331 non-null  object
#  13  purpose_category       21331 non-null  object
# dtypes: float64(1), int64(6), object(7)
# ...

# %%
data['debt'].unique()# Посмотрим какие есть значения в столбце с задолженостями 'debt'
# Out:
# array([0, 1])

# %%
data['children'].unique()# Посмотрим какие есть значения в столбце с детьми 'children'
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# *Создадим новую таблицу data_debt, отфильтруем только там где задолженность с признаком  == 1*

# %%
data_debt = data[data['debt'] == 1]# создадим новую таблицу и отфильтруем только там где задолженность с признаком 1
display(data_debt.head())
# Out:
#     children  days_employed  dob_years education  education_id  \
# 14         0    1844.956182         56    высшее             0
# 32         0    4649.910832         34   среднее             1
# 38         0     597.881827         25    высшее             0
# 55         0  365286.622650         54   среднее             1
# 75         1    2953.151948         38   среднее             1
#
#             family_status  family_status_id gender income_type  debt  \
# 14       гражданский брак                 1      F   компаньон     1
# 32       гражданский брак                 1      F   сотрудник     1
# 38  Не женат / не замужем                 4      M   сотрудник     1
# 55       гражданский брак                 1      F   пенсионер     1
# 75        женат / замужем                 0      M   сотрудник     1
#
#     total_income                     purpose total_income_category  \
# 14        165127  покупка жилой недвижимости                     C
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:**  При выводе на экран датафреймов лучше использовать метод `display()`, а не `print()`. Скорректируй здесь и далее.
#
# </div>
# <div class="alert alert-success">
#
# **Артём:** 👍 Спасибо, так удобнее изучать данные.
#
# </div>

# %% [markdown]
# *Cоздадим групировку(groupby) суммирования из столбцов количество детей и имел ли задолженность по возврату кредита*

# %%
# код групировки
data_children_group = data_debt.groupby('children')['debt'].sum()
display(data_children_group.sort_values(ascending=False))
# Out:
# children
# 0    1063
# 1     444
# 2     194
# 3      27
# 4       4
# Name: debt, dtype: int64

# %% [markdown]
# Создадим функцию что бы присвоить категории по кол-ву детей

# %%
def categoryze_children(children):
    """Эта супер функция присвоит категорийность по кол-ву детей:
    Детей нет, если = 0;
    До 2-х детей, если меньше или равно 2;
    3 и более детей. """
    if children == 0:
        return 'детей нет'
    if children <=2:
        return 'до 2-х детей'
    return '3 и более детей'

# %%
# добавим столбец 'category_children' где будут категории
data['category_children'] = data['children'].apply(categoryze_children)

# %%
display(data.head())
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose total_income_category          purpose_category  \
# ...

# %% [markdown]
# * Создадим сводную таблицу pivot_table *

# %%
categoryze_children_pivot_table = data.pivot_table(index='category_children', columns='debt', values='gender', aggfunc='count')

# %%
# просмотр сводной
display(categoryze_children_pivot_table)
# Out:
# debt                   0     1
# category_children
# 3 и более детей      349    31
# детей нет          13028  1063
# до 2-х детей        6222   638

# %%
# переименнуем название двух столбцов
categoryze_children_pivot_table.columns = ['there_is_no_debt', 'there_are_debts']

# %%
# просмотр сводной
display(categoryze_children_pivot_table)
# Out:
#                    there_is_no_debt  there_are_debts
# category_children
# 3 и более детей                 349               31
# детей нет                     13028             1063
# до 2-х детей                   6222              638

# %%
#добавим столбец общее количество заемщиков
categoryze_children_pivot_table['number_of_borrowers'] = categoryze_children_pivot_table['there_is_no_debt'] 
+ categoryze_children_pivot_table['there_are_debts']
# Out:
# category_children
# 3 и более детей      31
# детей нет          1063
# до 2-х детей        638
# Name: there_are_debts, dtype: int64

# %%
# просмотр сводной
display(categoryze_children_pivot_table)
# Out:
#                    there_is_no_debt  there_are_debts  number_of_borrowers
# category_children
# 3 и более детей                 349               31                  349
# детей нет                     13028             1063                13028
# до 2-х детей                   6222              638                 6222

# %%
# добавим столбец количесво задолженностей к общему 
categoryze_children_pivot_table['percentage_of_borrowers'] = categoryze_children_pivot_table['there_are_debts'] / categoryze_children_pivot_table['number_of_borrowers']

# %%
# Изменим формат столбца 'percentage_of_borrowers' в процентах (в супер пупер формат)
categoryze_children_pivot_table['percentage_of_borrowers'] = categoryze_children_pivot_table['percentage_of_borrowers'].map('{:.1%}'.format)

# %%
# просмотр сводной и отсортируем по убыванию
display(categoryze_children_pivot_table.sort_values(by='percentage_of_borrowers', ascending=False))
# Out:
#                    there_is_no_debt  there_are_debts  number_of_borrowers  \
# category_children
# 3 и более детей                 349               31                  349
# детей нет                     13028             1063                13028
# до 2-х детей                   6222              638                 6222
#
#                   percentage_of_borrowers
# category_children
# 3 и более детей                      8.9%
# детей нет                            8.2%
# до 2-х детей                        10.3%

# %% [markdown]
# <div class="alert alert-success">
#
# #### **Артём:** 👍 Когда комментарий или код прешывает 79 символов в строке - это стилистическая ошибка с точки зрения международных стандартов ([PEP 8](https://www.python.org/dev/peps/pep-0008/)) разработчиков на Python.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец, что смотришь данные отдельно.
#
# </div>
#
# <div class="alert alert-success">
#
# **Артём:**  Но в этом проекте важно отточить навык создания сводных таблиц.
#
# Сделай сводную таблицу методом `pivot_table или groupby` `здесь и далее` в которой буду следующая информация:
#
# 1. Название категории;
# 2. Количество клиентов в категории;
# 3. Доля задолженности.
#
# **Это важно сделать здесь и далее.** Подробнее можно почитать [здесь](https://dfedorov.spb.ru/pandas/Подробное%20руководство%20по%20группировке%20и%20агрегированию%20с%20помощью%20pandas.html?ysclid=lcmm6rtg2w602526506)
#
# Высшем пилотажем будет если проценты сразу выведешь в правильном формате, то есть умножишь на сто.
#
# </div>
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично.

# %% [markdown]
# **Вывод: Зависимость есть между количеством детей и возвратом кредита в срок, % задолженности больше у заемщиков которых от 1 до 2  детей**

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:**  Верно, если посмотреть кол-во тех кто выплачивает без просрочек, то картинка изменится. :)
#
# И так тоже будет некорректно смотреть.
#
# В этом и следующих пунктах нужно было посмотреть долю клиентов в группе имеющих задолженность, а не абсолютные числа. Например, из 100 человек долг есть у 99, а из 1000 у 200, где доля должников больше?
#
# **Артём:**  К сожалению, Вывод некорректный.
#
# </div>
# <div class="alert alert-success">
#
# **Артём:** 👍 Все верно.

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
data['family_status'].unique()# Посмотрим уникальные значения по статусам семейного положения
# Out:
# array(['женат / замужем', 'гражданский брак', 'вдовец / вдова',
#        'в разводе', 'Не женат / не замужем'], dtype=object)

# %%
data_family_status_group = data_debt.groupby('family_status')['debt'].sum()# создадим групировку суммирования из столбцов семейны статус с количесвтом задолжностей

# %%
display(data_family_status_group.sort_values(ascending=False))
# Out:
# family_status
# женат / замужем          927
# гражданский брак         385
# Не женат / не замужем    273
# в разводе                 84
# вдовец / вдова            63
# Name: debt, dtype: int64

# %%
# создадим сводную таблицу
categoryze_family_status_table = data.pivot_table(index='family_status', columns='debt', values='gender', aggfunc='count')

# %%
display(categoryze_family_status_table)
# Out:
# debt                       0    1
# family_status
# Не женат / не замужем   2523  273
# в разводе               1105   84
# вдовец / вдова           888   63
# гражданский брак        3749  385
# женат / замужем        11334  927

# %%
# переименнуем название двух столбцов
categoryze_family_status_table.columns = ['there_is_no_debt', 'there_are_debts']

# %%
display(categoryze_family_status_table)
# Out:
#                        there_is_no_debt  there_are_debts
# family_status
# Не женат / не замужем              2523              273
# в разводе                          1105               84
# вдовец / вдова                      888               63
# гражданский брак                   3749              385
# женат / замужем                   11334              927

# %%
#добавим столбец общее количество заемщиков
categoryze_family_status_table['number_of_borrowers'] = categoryze_family_status_table['there_is_no_debt'] + categoryze_family_status_table['there_are_debts']

# %%
display(categoryze_family_status_table)
# Out:
#                        there_is_no_debt  there_are_debts  number_of_borrowers
# family_status
# Не женат / не замужем              2523              273                 2796
# в разводе                          1105               84                 1189
# вдовец / вдова                      888               63                  951
# гражданский брак                   3749              385                 4134
# женат / замужем                   11334              927                12261

# %%
# добавим столбец количесво задолженностей к общему %
categoryze_family_status_table['percentage_of_borrowers'] = categoryze_family_status_table['there_are_debts'] / categoryze_family_status_table['number_of_borrowers']

# %%
# Изменим формат столбца 'percentage_of_borrowers' в процентах (в супер пупер формат)
categoryze_family_status_table['percentage_of_borrowers'] = categoryze_family_status_table['percentage_of_borrowers'].map('{:.1%}'.format)

# %%
display(categoryze_family_status_table.sort_values(by='percentage_of_borrowers', ascending=False))
# Out:
#                        there_is_no_debt  there_are_debts  number_of_borrowers  \
# family_status
# Не женат / не замужем              2523              273                 2796
# гражданский брак                   3749              385                 4134
# женат / замужем                   11334              927                12261
# в разводе                          1105               84                 1189
# вдовец / вдова                      888               63                  951
#
#                       percentage_of_borrowers
# family_status
# Не женат / не замужем                    9.8%
# гражданский брак                         9.3%
# женат / замужем                          7.6%
# в разводе                                7.1%
# вдовец / вдова                           6.6%

# %% [markdown]
# **Вывод: Зависимость есть между семейным положением и возвратом кредита в срок, меньше всего задолжностей по статусу вдовец / вдова **

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:**  Не совсем понятно на основании чего сделан вывод?
#
# ![image.png](attachment:image.png)
#
# </div>
# <div class="alert alert-success">
#
# **Артём:** 👍 Все верно.

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
data['total_income_category'].unique()# у нас был присвоен категоризм к доходу посмотрим зависмость с столбцом 'total_income_category'
# Out:
# array(['B', 'C', 'D', 'E', 'A'], dtype=object)

# %%
data_category_group = data_debt.groupby('total_income_category')['debt'].sum()# создадим групировку суммирования из столбцов категориями дохода с количесвтом задолжностей

# %%
print(data_category_group.sort_values(ascending=False))
# Out:
# total_income_category
# C    1353
# B     354
# D      21
# A       2
# E       2
# Name: debt, dtype: int64

# %%
# создадим сводную таблицу
categoryze_income_level_table = data.pivot_table(index='total_income_category', columns='debt', values='gender', aggfunc='count')

# %%
display(categoryze_income_level_table)
# Out:
# debt                       0     1
# total_income_category
# A                         23     2
# B                       4660   354
# C                      14568  1353
# D                        328    21
# E                         20     2

# %%
# переименнуем название двух столбцов
categoryze_income_level_table.columns = ['there_is_no_debt', 'there_are_debts']

# %%
#добавим столбец общее количество заемщиков
categoryze_income_level_table['number_of_borrowers'] = categoryze_income_level_table['there_is_no_debt'] + categoryze_income_level_table['there_are_debts']

# %%
# добавим столбец количесво задолженностей к общему %
categoryze_income_level_table['percentage_of_borrowers'] = categoryze_income_level_table['there_are_debts'] / categoryze_income_level_table['number_of_borrowers']

# %%
# Изменим формат столбца 'percentage_of_borrowers' в процентах (в супер пупер формат)
categoryze_income_level_table['percentage_of_borrowers'] = categoryze_income_level_table['percentage_of_borrowers'].map('{:.1%}'.format)

# %%
# Выведим на экран
display(categoryze_income_level_table.sort_values(by='percentage_of_borrowers', ascending=False))
# Out:
#                        there_is_no_debt  there_are_debts  number_of_borrowers  \
# total_income_category
# E                                    20                2                   22
# C                                 14568             1353                15921
# A                                    23                2                   25
# B                                  4660              354                 5014
# D                                   328               21                  349
#
#                       percentage_of_borrowers
# total_income_category
# E                                        9.1%
# C                                        8.5%
# A                                        8.0%
# B                                        7.1%
# D                                        6.0%

# %% [markdown]
# **Вывод: Зависимость есть,  по категории 50001–200000 — 'C' больше всего клиенты имеют задолженностей ;**

# %% [markdown]
# <div class="alert alert-success">
#
# #### **Артём:** 👍 Дам тебе совет на будущее, как лучше проводить категоризацию количественных данных. **В этом проекте переделывать ничего не надо, так как заказчик уже предложил свои категории, его стоит проинформировать, что выборки крайне несбалансированны.** Если только как дополнительное исследование.
#
# Сейчас самая маленькая категория в 728 раз меньше самой большой. Это может отразиться на результатах исследования. Когда мы делим на категории количественные данные, то лучше их делать примерно одинаковыми. Для этого можно воспользоваться методом `qcut()`. Пример:
#
# ```py
# pd.qcut(df['total_income'], 4)
# ```
#
# ```
# Name: total_income, Length: 21453, dtype: category
# Categories (4, interval[float64]): [(20666.999, 107620.0]  (107620.0, 142594.0]  (142594.0, 195818.0]  (195818.0, 2265604.0]]
# ```
#
# Что внутри:
#
# ```py
# pd.qcut(датафрейм['столбец'], количество_категорий)
# ```
#
# Итого у нас 4 категории:
# <ul>
#   <li>меньше 107_620</li>
#   <li>от 107_620 до 142_594</li>
#   <li>от 142_594 до 195_818</li>
#   <li>от 195_818</li>
#
# Пример использования:
# ```py
# # Создаем категории дохода с помощью pd.qcut
# data['total_qcut_category'] = pd.qcut(data['total_income'], 5, labels=['A', 'B', 'C', 'D', 'E'])
#
# # Группируем данные по новому столбцу 'total_income_category'
# pivot_table = data.groupby('total_qcut_category').agg(
#     borrowers=('debt', 'size'),
#     debtors=('debt', 'sum')
# ).reset_index()
# ```
#
# </ul>

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.

# %%
data_purpose_category_group = data_debt.groupby('purpose_category')['debt'].sum()# создадим групировку суммирования из столбцов категориями 'purpose_category' с количесвтом задолжностей

# %%
print(data_purpose_category_group.sort_values(ascending=False))
# Out:
# purpose_category
# операции с недвижимостью    780
# операции с автомобилем      400
# получение образования       369
# проведение свадьбы          183
# Name: debt, dtype: int64

# %%
# создадим сводную таблицу
categoryze_purpose_category_table = data.pivot_table(index='purpose_category', columns='debt', values='gender', aggfunc='count')

# %%
# переименнуем название двух столбцов
categoryze_purpose_category_table.columns = ['there_is_no_debt', 'there_are_debts']

# %%
#добавим столбец общее количество заемщиков
categoryze_purpose_category_table['number_of_borrowers'] = categoryze_purpose_category_table['there_is_no_debt'] + categoryze_purpose_category_table['there_are_debts']

# %%
# добавим столбец количесво задолженностей к общему 
categoryze_purpose_category_table['percentage_of_borrowers'] = categoryze_purpose_category_table['there_are_debts'] / categoryze_purpose_category_table['number_of_borrowers']

# %%
# добавим столбец количесво задолженностей к общему %
categoryze_purpose_category_table['percentage_of_borrowers'] = categoryze_purpose_category_table['there_are_debts'] / categoryze_purpose_category_table['number_of_borrowers']

# %%
# Изменим формат столбца 'percentage_of_borrowers' в процентах (в супер пупер формат)
categoryze_purpose_category_table['percentage_of_borrowers'] = categoryze_purpose_category_table['percentage_of_borrowers'].map('{:.1%}'.format)

# %%
display(categoryze_purpose_category_table.sort_values(by='percentage_of_borrowers', ascending=False))
# Out:
#                           there_is_no_debt  there_are_debts  \
# purpose_category
# операции с автомобилем                3879              400
# получение образования                 3619              369
# проведение свадьбы                    2130              183
# операции с недвижимостью              9971              780
#
#                           number_of_borrowers percentage_of_borrowers
# purpose_category
# операции с автомобилем                   4279                    9.3%
# получение образования                    3988                    9.3%
# проведение свадьбы                       2313                    7.9%
# операции с недвижимостью                10751                    7.3%

# %% [markdown]
# **Вывод: Операции с автобилем и получение образования по этим целям кредитования, самый большой процент должников.
# **

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:**  "Проведение свадьбы - меньше всего задолженностей" - это не так.
#
# </div>
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно.

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ: В основном все перечисленные данные это данные людей которые вводнят эти данные в базу люди, человеческий фактор*

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Согласен, человеческий фактор.
# </div>
#
# <div class="alert alert-success">
#
# **Артём:**  А какие еще варианты?
#
# </div>

# %% [markdown]
# Дополнительный ответ: Знчение могло изменится, когда дата сет распаковывался, так как он присваивает тип данных по первым 10 строкам.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Все верно, технический и человеческий факторы.
#
# </div>

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ: Среднее значение может быть не совсем объективным. медиана получается среднее от среднего и нет резкой разница в общих данных*

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец. Действительно важно учитывать, что в данных могут быть выбросы, которые могут сместить итоговый результат если использовать при заполнении данных среднее значение.
#
# </div>

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Напишите ваш общий вывод.

# %% [markdown]
#  Вопрос 1: Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %% [markdown]
# Самый высокий процет заемщиков с задолженностью с количеством детей от 1 до 2 (до 2-х детей)

# %% [markdown]
#  Вопрос 2: Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %% [markdown]
# Самый высокий процет заемщиков с задолженностями с семейным статусом Не женат / не замужем

# %% [markdown]
# Вопрос 3: Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %% [markdown]
# Категории дохода:
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.

# %% [markdown]
# Самый высокий процент по задолженностям с доходом - 0–30000 — `'E'`;

# %% [markdown]
# Вопрос 4: Как разные цели кредита влияют на его возврат в срок?

# %% [markdown]
# Самый высокий процент должников по целям заемщиков операции с автомобилем и получение образования.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:**  Промежуточные выводы будет смотреть старший аналитик, а заказчик будет читать финальный вывод и только его. Добавь информации о полученных результатах по каждому из четырех вопросов, разбей по пунктам, сделай красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить. Например, какие именно категории имеют наибольший процент невозврата кредитов, и почему? Учитывай для кого проведено исследование, в банковской сфере даже сотые доли процента играют роль, но в нашем можно ограничиться десятыми. Помни, вывод – это лицо дата специалиста. 😉
#
# **Артём:**  В выводе лучше не писать код, только вывод. Но если решишь добавть код, то важно убедиться, что он работает до конца.
#
# ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.

# %% [markdown]
# ## 🏁 Итоги ревью
# <a id="results"></a>
# [В начало](#start)
#
#
# <div class="alert alert-danger">
#
# **Артём:** ❌ Оксана, спасибо за работу. Осталось исправить несколько комментариев и можно идти к заказчику. Молодец! 👍
#
# Для удобства, комментарии которые нужно скорректировать я добавил в меню **Contents** слева.
#
# Жду новую версию проекта. 🙂
#
# </div>
# <div class="alert alert-danger">
#
# **Артём:** ❌ Оксана, осталось исправить три комментариея и проект можно принять.

# %% [markdown]
# <img src="https://s19536.pcdn.co/wp-content/uploads/2020/06/Web-Great-Job.jpg">
# <div class="alert alert-success">
#
# **Артём:** ✌️ Оксана, спасибо за работу и внесенные корректировки! Критических замечаний нет.
#
#
# Поздравляю, **проект принят!** 🥳 🎉 Ты молодец!
#
# Желаю тебе успехов в дальнейшем обучении. 😉
#
# ---
#
# #### 📖 **Полезные ссылки**
#
# * [Работа в Яндексе](https://yandex.ru/jobs/pages/analytics_interview?ysclid=l84s63fs1g790141490)
# * [Настройте свой Jupyter Notebook правильно](https://medium.com/nuances-of-programming/настройте-свой-jupyter-notebook-правильно-faef14c89434)
# * [Краткое руководство по Маркдауну](https://paulradzkov.com/2014/markdown_cheatsheet/?)
# * [PEP 8 – Style Guide for Python Code](https://www.python.org/dev/peps/pep-0008/)
# * [Обработка пропусков в данных](https://loginom.ru/blog/missing)
# * [Разделение данных с помощью qcut и cut в Pandas](https://dfedorov.spb.ru/pandas/Разделение%20данных%20в%20Pandas%20с%20помощью%20qcut%20и%20cut.html?)
# * [Официальная документаци метода qcut](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html)
# * [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/Подробное%20руководство%20по%20группировке%20и%20агрегированию%20с%20помощью%20pandas.html?ysclid=lcmm6rtg2w602526506)
# * [Проверка статистических гипотез. (21 мая 2020 г.)](https://allatambov.github.io/psms/pdf/hypo-test.pdf)
# * [Шпаргалка по визуализации данных в Python с помощью Plotly](https://habr.com/ru/articles/502958/)
# * [Тест гигиены визуализации данных](https://bar-or-pie.dianov.org)
# * [Задачки SQL](https://habr.com/ru/company/dcmiran/blog/500360/)
# * [7 cайтов для оттачивания навыка написания SQL запросов на 2020 год](https://techrocks.ru/2019/11/22/7-sites-to-perfect-sql-query-writing-skills/)
# * [Главред помогает очистить текст от словесного мусора, проверяет на соответствие информационному стилю.](https://glvrd.ru)
#
# </div>
